# %%
continuation of String Datatupes:

# %%
Introduction of F Strings:

# %%
firstname ="Tania"
lastname ="Afroze"
print(firstname)
# Out:
# Tania

# %%
#1.req "want to get the full name

# %%
#general Syntax of f string:

# %%
# message= f"custom message{place_holder_1}{place_holder_2}..........{place_holder_n}"
fullname = f"{firstname} {lastname}"
print(fullname)
# Out:
# Tania Afroze

# %%
message = f"Keep up the good work,{fullname.title()}"
print(message)
# Out:
# Keep up the good work,Keep Up The Good Work,Keep Up The Good Work,Tania Afroze

# %%
Adding whitespaces to Strings:

# %%
print("favourite_Programming_Language:Python")
# Out:
# favourite_Programming_Language:Python

# %%
print("favourite_Programming_Language:Python\nC++\nJava\nC#\nSQL")
# Out:
# favourite_Programming_Language:Python
# C++
# Java
# C#
# SQL

# %%
# \n ------> is called a new line delimiter

# %%
print("favourite_Programming_Language:\n\tPython\n\tC++\n\tJava\n\tC#\n\tSQL")
# Out:
# favourite_Programming_Language:
# 	Python
# 	C++
# 	Java
# 	C#
# 	SQL

# %%
# \t ------> is called a tab delimiter

# %%
Removing Whitespaces from String:

# %%
name = 'python'
print(name)
# Out:
# python

# %%
name2 = '  python'
print(name2)
# Out:
#   python

# %%
name3 = '  python  '
print(name3)
# Out:
#   python

# %%
name2.lstrip()
# Out:
# 'python'

# %%
name3.rstrip()
# Out:
# '  python'

# %%
name4 = '  python  '
print(name4)
# Out:
#   python

# %%
name4.strip()
# Out:
# 'python'

# %%
Introduction to number:

# %%
Integers:

# %%
num = 123
print(num)
# Out:
# 123

# %%
type(num)
# Out:
# int

# %%
Floats #Decimals

# %%
test =0.1
print(test)
# Out:
# 0.1

# %%
type(test)
# Out:
# float

# %%
# Note:Python is case
