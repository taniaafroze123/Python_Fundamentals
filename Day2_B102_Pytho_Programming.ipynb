# %%
indroduction to variables:

# %%
a=1
b=2
c = a+b
print(c)
# Out:
# 3

# %%
Rules for Declaring the Variables:

# %%
1.No namespace

# %%
first name='Tania'
# Out:
#   Cell In[5], line 1
#     first name='Tania'
#           ^
# SyntaxError: invalid syntax

# %%
firstname= "tania"
print(firstname)
# Out:
# tania

# %% [markdown]
# 2.Variable should not start with the number **

# %%
1name='sun'
print(1name)
# Out:
#   Cell In[14], line 1
#     1name='sun'
#     ^
# SyntaxError: invalid decimal literal

# %%
name1='sun'
print(name1)
# Out:
# sun

# %%
3.Variable should not contain special characters(@#$%^&*)

# %%
@name="moon"
print(@name)
# Out:
#   Cell In[16], line 1
#     @name="moon"
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
Data types in Python:
1.string ----- str
2.numbers ---------int,float
3.list --------- list
4.tuples -------- tuple
5.dictionaries ------- dict

# %%
Classification Of DataTypes:
1.Mutable - which can be edited or altered
2.Immutable - which cannot be edited or altered

# %%
Introduction to string DataTypes:
1.Defination-String is a series of characters declared in quotes
2.classification-immutable datatype
3.string can be defined in single and double quotes

# %%
name1='tania'
name2="afroze"
print(name1)
print(name2)
# Out:
# tania
# afroze

# %%
String Methods:

# %%
type(name1)
# Out:
# str

# %%
print(name1.title())
# Out:
# Tania

# %%
print(name1.upper())
# Out:
# TANIA

# %%
print(name1.lower())
# Out:
# tania
