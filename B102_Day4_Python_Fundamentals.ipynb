# %%
Introduction to List Datatypes:

# %%
Defination: A list is a collection of items declared in a particular order.
classification: it is classifed as a mutable datatype
how to define a list ---[]

# %%
students =['tania','suhana','ramya','indu']

# %%
print(students)
# Out:
# ['tania', 'suhana', 'ramya', 'indu']

# %%
type(students)
# Out:
# list

# %%
Introduction to indexing:0,1,2,3,4,5,.................n

# %%
how to access the element from the list
how to modify the element from the list
how to declare the elements from the list

# %%
# i want to access suhana frome the above list.

# %%
print(students[1])
# Out:
# suhana

# %%
print(students[1].title())
# Out:
# Suhana

# %%
# i want to appriciate

# %%
print(f"keep up the good work,{students[0].title()}")
# Out:
# keep up the good work,Tania

# %%
students.append("Ram")

# %%
print(students)
# Out:
# ['tania', 'suhana', 'ramya', 'indu', 'Ram']

# %%
students.insert(3
